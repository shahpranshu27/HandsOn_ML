# %% [markdown]
# <a href="https://colab.research.google.com/github/shahpranshu27/HandsOn_ML/blob/main/01_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'],df['price'], marker='+', color='red')
plt.xlabel('Area')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
model = LinearRegression()
model.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
model.predict([[3300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
area_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/areas.csv")
area_df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p = model.predict(area_df)

# %%
area_df['prices'] = p
area_df
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
area_df.to_csv("/content/drive/MyDrive/Colab Notebooks/predictions.csv")
