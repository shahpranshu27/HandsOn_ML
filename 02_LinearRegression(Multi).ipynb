# %% [markdown]
# <a href="https://colab.research.google.com/github/shahpranshu27/HandsOn_ML/blob/main/02_LinearRegression(Multi).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/homeprices1.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.describe()
# Out:
#               area  bedrooms        age          price
# count     6.000000   5.00000   6.000000       6.000000
# mean   3416.666667   4.20000  16.500000  648333.333333
# std     587.934237   1.30384   8.288546  109117.673484
# min    2600.000000   3.00000   8.000000  550000.000000
# 25%    3050.000000   3.00000   9.750000  572500.000000
# 50%    3400.000000   4.00000  16.500000  602500.000000
# 75%    3900.000000   5.00000  19.500000  722500.000000
# max    4100.000000   6.00000  30.000000  810000.000000

# %%
import math
median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 4

# %%
df.bedrooms.fillna(median_bedrooms, inplace=True)
df
# Out:
# <ipython-input-5-d5b11b335e3e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.bedrooms.fillna(median_bedrooms, inplace=True)
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
model = LinearRegression()
model.fit(df[['area', 'bedrooms', 'age']], df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
model.intercept_
# Out:
# 221323.00186540396

# %%
model.predict([[3000, 3, 40]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])

# %%
model.predict([[2500, 4, 5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])

# %% [markdown]
# **Exercise**

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/hiring.csv")
df1
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
# !pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=46b8f60e7cbad12a86e8c071e518725b215938d7c10380804411cc31a9bc3ffc
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built word2number
# ...

# %%
from word2number import w2n

# Step 2: Define a function to convert words to numbers
def convert_words_to_numbers(word):
    try:
        return w2n.word_to_num(word)
    except ValueError:
        return None  # or handle the error as needed

# Step 3: Apply the conversion function to the specific column
# Replace 'column_name' with the name of the column you want to convert
df1['experience'] = df1['experience'].apply(convert_words_to_numbers)

# Step 4: Save the modified DataFrame back to a CSV file
df1.to_csv('hiring.csv', index=False)  # Replace 'output.csv' with your desired output file path

# %%
df1
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         NaN                    8.0                           9      50000
# 1         NaN                    8.0                           6      45000
# 2         5.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6        10.0                    NaN                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
df1.experience.fillna(0, inplace=True)
df1
# Out:
# <ipython-input-19-1d277993d800>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1.experience.fillna(0, inplace=True)
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         0.0                    8.0                           9      50000
# 1         0.0                    8.0                           6      45000
# 2         5.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# ...

# %%
df1['test_score(out of 10)'].fillna(df1['test_score(out of 10)'].median(), inplace=True)
df1
# Out:
# <ipython-input-25-bfef2a0e9fe4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['test_score(out of 10)'].fillna(df1['test_score(out of 10)'].median(), inplace=True)
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         0.0                    8.0                           9      50000
# 1         0.0                    8.0                           6      45000
# 2         5.0                    6.0                           7      60000
# ...

# %%
model.fit(df1[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']], df1['salary($)'])
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
model.intercept_
# Out:
# 17737.263464337688

# %%
model.predict([[2, 9, 6]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %%
model.predict([[12, 10, 10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92002.18340611])
